# %%
import pandas as pd
from yelpapi import YelpAPI
import os, json, math, time
from tqdm.notebook import tqdm_notebook

# %%
# Load credentials
with open('/Users/caell/.secret/yelp_api.json') as f:
    login = json.load(f)
    
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)

# %%
LOCATION = 'San Diego, CA'
TERM = 'Sushi'

# %%
JSON_FILE = 'Data/in_progress_yelp_sd_sushi.json'

# %%
def create_json_file(JSON_FILE, delete_if_exists=True):
    file_exists = os.path.isfile(JSON_FILE)
    
    if file_exists:
        
        if delete_if_exists:
            print(f'{JSON_FILE} exists, deleting file')
            os.remove(JSON_FILE)
            create_json_file(JSON_FILE)
        else:
            print(f'{JSON_FILE} already exists')
    
    else:
        print(f'{JSON_FILE} does not exists, creating new file as empty list')
        folder = os.path.dirname(JSON_FILE)
        if len(folder) > 0:
            os.makedirs(folder, exist_ok=True)
        with open(JSON_FILE, 'w') as f:
            json.dump([],f)

# %%
create_json_file(JSON_FILE)
# Out:
# Data/in_progress_yelp_sd_sushi.json exists, deleting file
# Data/in_progress_yelp_sd_sushi.json does not exists, creating new file as empty list

# %%
with open(JSON_FILE, 'r') as f:
    previous_results = json.load(f)

n_results = len(previous_results)
print(f'{n_results} previous results found')
results = yelp_api.search_query(location=LOCATION,
                          term=TERM,
                         offset=n_results)
total_results = results['total']
results_per_page = len(results['businesses'])

print(f'downloading {results_per_page} results per page')

n_pages = math.ceil((total_results - n_results) / results_per_page)

print(f'{n_pages} pages remaining to download')
# Out:
# 0 previous results found
# downloading 20 results per page
# 65 pages remaining to download

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    with open(JSON_FILE, 'r') as f:
        previous_results = json.load(f)
    
    n_results = len(previous_results)
    
    if n_results + results_per_page > 1000:
        print('Exceeded 1000 call limit, stopping loop')
        break
    
    results = yelp_api.search_query(location=LOCATION,
                                   term=TERM,
                                   offset=n_results)
    
    previous_results.extend(results['businesses'])
    
    with open(JSON_FILE, 'w') as f:
        json.dump(previous_results, f)
        
    time.sleep(.2)
print(f'{len(previous_results)} results successfully retrieved')
# Out:
#   0%|          | 0/65 [00:00<?, ?it/s]
# Exceeded 1000 call limit, stopping loop
# 1000 results successfully retrieved

# %%
final_df = pd.read_json(JSON_FILE)
display(final_df.head(), final_df.tail())
# Out:
#                        id                      alias             name  \
# 0  O1NFJA0OI0-N77JzP7qlfQ    azuki-sushi-san-diego-2      Azuki Sushi
# 1  iFrXIJmSiEjlEHuakTaKnA        kumi-cafe-san-diego        Kumi Cafe
# 2  3S6VtYgcXL8lRic0iV5GYQ        sushi-ota-san-diego        Sushi Ota
# 3  werz_RjIeFEFNflwl6kdXA  sushi-yorimichi-san-diego  Sushi Yorimichi
# 4  TSYhYwOPeaZmRNuiJoZaAw   soichi-sushi-san-diego-2     Soichi Sushi
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/OhZXVg...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/xfe9-W...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/MtEcy_...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/zFNNEO...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/dDCfEd...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/azuki-sushi-san-diego...          2644
# 1  https://www.yelp.com/biz/kumi-cafe-san-diego?a...           135
# 2  https://www.yelp.com/biz/sushi-ota-san-diego?a...          4234
# 3  https://www.yelp.com/biz/sushi-yorimichi-san-d...           123
# 4  https://www.yelp.com/biz/soichi-sushi-san-dieg...           364
#
#                                           categories  rating  \
# 0  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 1  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 2  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 3  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 4  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     5.0
#
#                                          coordinates  \
# 0  {'latitude': 32.7296447753906, 'longitude': -1...
# 1     {'latitude': 32.81971, 'longitude': -117.1494}
# 2  {'latitude': 32.8036636, 'longitude': -117.217...
# 3    {'latitude': 32.78695, 'longitude': -117.17053}
# 4     {'latitude': 32.76267, 'longitude': -117.1418}
#
#                                  transactions price  \
# 0  [delivery, restaurant_reservation, pickup]    $$
# 1  [delivery, restaurant_reservation, pickup]    $$
# 2                                  [delivery]   $$$
# 3  [delivery, restaurant_reservation, pickup]    $$
# 4                          [delivery, pickup]  $$$$
#
#                                             location         phone  \
# 0  {'address1': '2321 5th Ave', 'address2': '', '...  +16192384760
# 1  {'address1': '4380 Kearny Mesa Rd', 'address2'...  +18585651288
# 2  {'address1': '4529 Mission Bay Dr', 'address2'...  +18588808778
# 3  {'address1': '2405 Ulric St', 'address2': None...  +18582796868
# 4  {'address1': '2121 Adams Ave', 'address2': '',...  +16196772220
#
#     display_phone     distance
# 0  (619) 238-4760  6796.380089
# 1  (858) 565-1288  3269.091429
# 2  (858) 880-8778  6032.314235
# 3  (858) 279-6868  1599.327274
# 4  (619) 677-2220  3309.247571
#                          id                                        alias  \
# 995  l8M3vNqlAKN_s8NiSVBZ2w       board-and-brew-scripps-ranch-san-diego
# 996  3jYKnm8jHcjaVkt6mRSoIQ  francos-flapjack-family-restaurant-bonita-2
# 997  mtWpuuIdsHzKYMjUcxSPyw                        jalisco-cafe-bonita-2
# 998  IjBYMYnzrs6IdwRRHkKZGA                       berts-bistro-san-diego
# 999  j0cLQdianbAcvZeM97uWyA       home-brew-mart-ballast-point-san-diego
#
#                                     name  \
# 995         Board & Brew - Scripps Ranch
# 996  Franco's Flapjack Family Restaurant
# 997                         Jalisco Cafe
# 998                        Bert's Bistro
# 999       Home Brew Mart - Ballast Point
#
#                                              image_url  is_closed  \
# 995  https://s3-media2.fl.yelpcdn.com/bphoto/oKIL30...      False
# 996  https://s3-media4.fl.yelpcdn.com/bphoto/lFbxHT...      False
# 997  https://s3-media3.fl.yelpcdn.com/bphoto/2oBhF4...      False
# 998  https://s3-media4.fl.yelpcdn.com/bphoto/hCdjR_...      False
# 999  https://s3-media2.fl.yelpcdn.com/bphoto/nyz7xi...      False
#
#                                                    url  review_count  \
# 995  https://www.yelp.com/biz/board-and-brew-scripp...           950
# 996  https://www.yelp.com/biz/francos-flapjack-fami...           779
# 997  https://www.yelp.com/biz/jalisco-cafe-bonita-2...           261
# 998  https://www.yelp.com/biz/berts-bistro-san-dieg...             8
# 999  https://www.yelp.com/biz/home-brew-mart-ballas...           468
#
#                                             categories  rating  \
# 995  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     4.5
# 996  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
# 997         [{'alias': 'mexican', 'title': 'Mexican'}]     3.0
# 998             [{'alias': 'cafes', 'title': 'Cafes'}]     3.0
# 999  [{'alias': 'breweries', 'title': 'Breweries'},...     4.0
#
#                                            coordinates        transactions  \
# 995    {'latitude': 32.91559, 'longitude': -117.11459}          [delivery]
# 996  {'latitude': 32.6589957193909, 'longitude': -1...  [pickup, delivery]
# 997  {'latitude': 32.658179195321324, 'longitude': ...  [pickup, delivery]
# 998  {'latitude': 32.771885, 'longitude': -117.194577}                  []
# 999  {'latitude': 32.7667841646776, 'longitude': -1...          [delivery]
#
#     price                                           location         phone  \
# 995    $$  {'address1': '9880 Hibert St', 'address2': 'St...  +18586892739
# 996    $$  {'address1': '4164 Bonita Rd', 'address2': '',...  +16195121673
# 997     $  {'address1': '4026 Bonita Rd', 'address2': '',...  +16192677855
# 998    $$  {'address1': 'University Of San Diego', 'addre...
# 999     $  {'address1': '5401 Linda Vista Rd', 'address2'...  +16192952337
#
#       display_phone      distance
# 995  (858) 689-2739  14381.278559
# 996  (619) 512-1673  18250.672462
# 997  (619) 267-7855  18187.817299
# 998                   4318.254525
# 999  (619) 295-2337   4669.792839

# %%
final_df.duplicated(subset='id').sum()
# Out:
# 7

# %%
final_df.drop_duplicates(subset='id', inplace=True)
final_df.duplicated(subset='id').sum()
# Out:
# 0

# %%
final_df.to_csv('Data/final_SD_sushi_spots.csv.gz',
               compression='gzip', index=False)

# %%
test_df = pd.read_csv('Data/final_SD_sushi_spots.csv.gz')
test_df.head()
# Out:
#                        id                      alias             name  \
# 0  O1NFJA0OI0-N77JzP7qlfQ    azuki-sushi-san-diego-2      Azuki Sushi
# 1  iFrXIJmSiEjlEHuakTaKnA        kumi-cafe-san-diego        Kumi Cafe
# 2  3S6VtYgcXL8lRic0iV5GYQ        sushi-ota-san-diego        Sushi Ota
# 3  werz_RjIeFEFNflwl6kdXA  sushi-yorimichi-san-diego  Sushi Yorimichi
# 4  TSYhYwOPeaZmRNuiJoZaAw   soichi-sushi-san-diego-2     Soichi Sushi
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/OhZXVg...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/xfe9-W...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/MtEcy_...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/zFNNEO...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/dDCfEd...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/azuki-sushi-san-diego...          2644
# 1  https://www.yelp.com/biz/kumi-cafe-san-diego?a...           135
# 2  https://www.yelp.com/biz/sushi-ota-san-diego?a...          4234
# 3  https://www.yelp.com/biz/sushi-yorimichi-san-d...           123
# 4  https://www.yelp.com/biz/soichi-sushi-san-dieg...           364
#
#                                           categories  rating  \
# 0  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 1  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 2  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 3  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 4  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     5.0
#
#                                          coordinates  \
# 0  {'latitude': 32.7296447753906, 'longitude': -1...
# 1     {'latitude': 32.81971, 'longitude': -117.1494}
# 2  {'latitude': 32.8036636, 'longitude': -117.217...
# 3    {'latitude': 32.78695, 'longitude': -117.17053}
# 4     {'latitude': 32.76267, 'longitude': -117.1418}
#
#                                        transactions price  \
# 0  ['delivery', 'restaurant_reservation', 'pickup']    $$
# 1  ['delivery', 'restaurant_reservation', 'pickup']    $$
# 2                                      ['delivery']   $$$
# 3  ['delivery', 'restaurant_reservation', 'pickup']    $$
# 4                            ['delivery', 'pickup']  $$$$
#
#                                             location         phone  \
# 0  {'address1': '2321 5th Ave', 'address2': '', '...  1.619238e+10
# 1  {'address1': '4380 Kearny Mesa Rd', 'address2'...  1.858565e+10
# 2  {'address1': '4529 Mission Bay Dr', 'address2'...  1.858881e+10
# 3  {'address1': '2405 Ulric St', 'address2': None...  1.858280e+10
# 4  {'address1': '2121 Adams Ave', 'address2': '',...  1.619677e+10
#
#     display_phone     distance
# 0  (619) 238-4760  6796.380089
# 1  (858) 565-1288  3269.091429
# 2  (858) 880-8778  6032.314235
# 3  (858) 279-6868  1599.327274
# 4  (619) 677-2220  3309.247571
