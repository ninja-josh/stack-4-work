# %% [markdown]
# # Advanced Transformations Core Assignment
#
# * Josh Johnson
# * Data Enrichment
# * 11/22/2022

# %%
# Imports
import pandas as pd
import json

# %%
# Load and examine the info file
super_info = pd.read_csv('Data/superhero_info - superhero_info.csv')
super_info.info()
super_info.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Measurements    463 non-null    object
# dtypes: object(8)
# memory usage: 29.1+ KB
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# ...

# %% [markdown]
# # Transform Superhero Info

# %% [markdown]
# ## Split Hero and Publisher

# %%
# split the Hero/Publisher column into 2 columns and drop 'Hero|Publisher'
super_info[['Hero', 'Publisher']] = \
super_info['Hero|Publisher'].str.split('|', expand=True)
super_info.drop('Hero|Publisher', axis=1, inplace=True)

super_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %% [markdown]
# ## Split Measurements

# %%
# Check datatype of 'Measurements'
super_info.loc[0, 'Measurements']
# Out:
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %%
# Replace single quotes with double quotes for json
super_info['Measurements'] = super_info['Measurements'].str.replace("'", '"')
super_info.loc[0, 'Measurements']
# Out:
# '{"Height": "203.0 cm", "Weight": "441.0 kg"}'

# %%
# Transform the string to a list
super_info['Measurements'] = super_info['Measurements'].apply(json.loads)

# %%
# Expand the list to separate columns, Height and Weight
super_info[['Height', 'Weight']] = super_info['Measurements'].apply(pd.Series)
super_info.drop('Measurements', axis=1, inplace=True)
super_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Height    Weight
# 0         A-Bomb      Marvel Comics  203.0 cm  441.0 kg
# 1     Abe Sapien  Dark Horse Comics  191.0 cm   65.0 kg
# 2       Abin Sur          DC Comics  185.0 cm   90.0 kg
# 3    Abomination      Marvel Comics  203.0 cm  441.0 kg
# 4  Absorbing Man      Marvel Comics  193.0 cm  122.0 kg

# %% [markdown]
# ## Convert Height and Weight to numeric

# %%
# Clean up Height and Weight and convert to float
super_info['Height'] = super_info['Height'].str.replace(' cm', '').astype(float)
super_info['Weight'] = super_info['Weight'].str.replace(' kg', '').astype(float)
super_info.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight
# 0         A-Bomb      Marvel Comics   203.0   441.0
# 1     Abe Sapien  Dark Horse Comics   191.0    65.0
# 2       Abin Sur          DC Comics   185.0    90.0
# 3    Abomination      Marvel Comics   203.0   441.0
# 4  Absorbing Man      Marvel Comics   193.0   122.0

# %% [markdown]
# # Super_powers

# %%
# Load and examine the powers file
super_powers = pd.read_csv('Data/superhero_powers - superhero_powers.csv')
super_powers.info()
super_powers.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
# Examine the first element in Powers
super_powers.loc[0,'Powers']
# Out:
# 'Agility,Super Strength,Stamina,Super Speed'

# %%
# Convert the string of powers to a list of powers
Powers = super_powers['Powers'].str.split(',')

# %%
# explode the list of powers into one row per hero per power
exploded = Powers.explode('Powers')

# Get a list of the unique powers
cols_to_make = exploded.dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
# One-hot encode the powers
for col in cols_to_make:
    super_powers[col] = super_powers['Powers'].str.contains(col)
super_powers
# Out:
# C:\Users\caell\AppData\Local\Temp\ipykernel_13020\499319253.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super_powers[col] = super_powers['Powers'].str.contains(col)
# C:\Users\caell\AppData\Local\Temp\ipykernel_13020\499319253.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super_powers[col] = super_powers['Powers'].str.contains(col)
# ...

# %%
# defragging the dataframe
super_powers = super_powers.copy()

# %%
# merge info and powers dataframes
SuperHeroes = pd.merge(super_info, super_powers, 
                       left_on='Hero', right_on='hero_names')
SuperHeroes.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height  Weight  ... Weather Control  \
# 0         A-Bomb      Marvel Comics   203.0   441.0  ...           False
# 1     Abe Sapien  Dark Horse Comics   191.0    65.0  ...           False
# 2       Abin Sur          DC Comics   185.0    90.0  ...           False
# 3    Abomination      Marvel Comics   203.0   441.0  ...           False
# 4  Absorbing Man      Marvel Comics   193.0   122.0  ...           False
#
#   Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# ...

# %%
SuperHeroes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 463 entries, 0 to 462
# Columns: 179 entries, Gender to Changing Armor
# dtypes: bool(167), float64(2), object(10)
# memory usage: 122.5+ KB

# %% [markdown]
# # Questions:
#
# ## Compare the average weight of super powers who have Super Speed to those who do not.

# %%
# replacing True and False with 1 and 0
# Not sure if this is necessary, but it's what I'm used to seeing
SuperHeroes = SuperHeroes.replace([True, False], [1, 0])

# %%
# create a df of just speedy heroes
speed = SuperHeroes[SuperHeroes['Super Speed'] == True]
speed['Super Speed'].value_counts()
# Out:
# 1    198
# Name: Super Speed, dtype: int64

# %%
# create a df of slower heroes
no_speed = SuperHeroes[~(SuperHeroes['Super Speed'] == True)]
no_speed.head()
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
# 2   Male        Ungaran      good    No Hair      blue        red
# 4   Male          Human       bad    No Hair      blue    Unknown
# 6   Male          Human      good      Brown     brown    Unknown
#
#             Hero          Publisher  Height  Weight  ... Weather Control  \
# 0         A-Bomb      Marvel Comics   203.0   441.0  ...               0
# 1     Abe Sapien  Dark Horse Comics   191.0    65.0  ...               0
# 2       Abin Sur          DC Comics   185.0    90.0  ...               0
# 4  Absorbing Man      Marvel Comics   193.0   122.0  ...               0
# 6      Agent Bob      Marvel Comics   178.0    81.0  ...               0
#
#   Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# ...

# %%
# print the average weights of speedy and slower heroes
print('Speedy Weights = ', speed['Weight'].mean())
print('Slow Weights = ', no_speed['Weight'].mean())
# Out:
# Speedy Weights =  129.40404040404042
# Slow Weights =  101.77358490566037

# %% [markdown]
# ## What is the average height of heroes for each publisher?

# %%
# Group df by Publisher and aggregate by mean.  Display the grouped Height column
SuperHeroes.groupby('Publisher')['Height'].mean()
# Out:
# Publisher
# DC Comics            181.923913
# Dark Horse Comics    176.909091
# George Lucas         159.600000
# Image Comics         211.000000
# Marvel Comics        191.546128
# Shueisha             171.500000
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Name: Height, dtype: float64
